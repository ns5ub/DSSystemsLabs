# %% [markdown]
# # Data Analysis
#
# Importing relevant analysis tools and importing data collected over the course of an hour and stored in a SQLLite database.

# %%
import numpy as np
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

# %%
con = sqlite3.connect("api_data.db")
df = pd.read_sql_query("SELECT * from data", con)

print(df.head())

con.close()
# Out:
#    factor        pi                 time
# 0       1  4.000000  2022-05-06 00:00:00
# 1       1  4.000000  2022-05-06 00:01:00
# 2       8  3.017072  2022-05-06 00:02:00
# 3      27  3.178617  2022-05-06 00:03:00
# 4      64  3.125969  2022-05-06 00:04:00

# %% [markdown]
# Transforming time column into a datetime type, and then extracting the minute into it's own column

# %%
df['time'] =  pd.to_datetime(df['time'], format='%Y-%m-%d %H:%M:%S')
df['minute'] = df['time'].dt.minute
print(df.head())
# Out:
#    factor        pi                time  minute
# 0       1  4.000000 2022-05-06 00:00:00       0
# 1       1  4.000000 2022-05-06 00:01:00       1
# 2       8  3.017072 2022-05-06 00:02:00       2
# 3      27  3.178617 2022-05-06 00:03:00       3
# 4      64  3.125969 2022-05-06 00:04:00       4

# %% [markdown]
# ## Factor Column
#
# The factor column is the minute of the timestamp to the third power likely - graphing and testing that theory.

# %%
df.plot(kind = 'scatter', x = 'minute', y = 'factor')
# Out:
# <AxesSubplot:xlabel='minute', ylabel='factor'>

# %% [markdown]
# Initial graph confirms this, graphing against x^3...

# %%
plt.scatter(df['minute'], df['factor'], label = "Collected Data", s=8)

x = np.arange(0, 60, 1)
y = x**3
plt.plot(x,y, color = "r", label = "x^3")
plt.show()

# %% [markdown]
# ## Pi Column
#
# The pi column is clearly converging to pi (3.14) and is oscillating around that value.

# %% [markdown]
# Not sure what the exact function is. Googling the problem seems to point that this may be a dampened cos function - they have a factor which makes sense
#
# https://www.calculushowto.com/calculus-definitions/damped-sine-wave/

# %%
plt.scatter(df['minute'], df['pi'], label = "Collected Data", s=8)
plt.plot(df['minute'], df['pi'], label = "Connected", c='r')
x = np.arange(1, 60, 1)
y = (1/(x**3)) + np.pi
plt.plot(x, y, label = "factor column + pi", c='g')
plt.show()

# %% [markdown]
# Potential Testing reveals this isn't the case exactly.

# %%
plt.scatter(df['minute'], df['pi'], label = "Collected Data", s=8)
x = np.arange(1, 60, 1)
x_3 = x**3
y = (1/(x**3)) * np.cos(x) + np.pi
plt.plot(x, y, label = "Theoretical", c='r')

# %%
df['test'] = df['pi'] - np.pi
df['test2'] = 1/df['factor']
print(df.head(30))
# Out:
#     factor        pi                time  minute      test     test2  \
# 0        1  4.000000 2022-05-06 00:00:00       0  0.858407  1.000000
# 1        1  4.000000 2022-05-06 00:01:00       1  0.858407  1.000000
# 2        8  3.017072 2022-05-06 00:02:00       2 -0.124521  0.125000
# 3       27  3.178617 2022-05-06 00:03:00       3  0.037024  0.037037
# 4       64  3.125969 2022-05-06 00:04:00       4 -0.015624  0.015625
# 5      125  3.149593 2022-05-06 00:05:00       5  0.008000  0.008000
# 6      216  3.136963 2022-05-06 00:06:01       6 -0.004630  0.004630
# 7      343  3.144508 2022-05-06 00:07:01       7  0.002915  0.002915
# 8      512  3.139640 2022-05-06 00:08:01       8 -0.001953  0.001953
# 9      729  3.142964 2022-05-06 00:09:01       9  0.001372  0.001372
# 10    1000  3.140593 2022-05-06 00:10:01      10 -0.001000  0.001000
# 11    1331  3.142344 2022-05-06 00:11:01      11  0.000751  0.000751
# 12    1728  3.141014 2022-05-06 00:12:02      12 -0.000579  0.000579
# 13    2197  3.142048 2022-05-06 00:13:02      13  0.000455  0.000455
# 14    2744  3.141228 2022-05-06 00:14:02      14 -0.000364  0.000364
# 15    3375  3.141889 2022-05-06 00:15:02      15  0.000296  0.000296
# 16    4096  3.141349 2022-05-06 00:16:02      16 -0.000244  0.000244
# 17    4913  3.141796 2022-05-06 00:17:02      17  0.000204  0.000204
# 18    5832  3.141421 2022-05-06 00:18:02      18 -0.000171  0.000171
# 19    6859  3.141738 2022-05-06 00:19:03      19  0.000146  0.000146
# 20    8000  3.141468 2022-05-06 00:20:03      20 -0.000125  0.000125
# 21    9261  3.141701 2022-05-06 00:21:03      21  0.000108  0.000108
# 22   10648  3.141499 2022-05-06 00:22:03      22 -0.000094  0.000094
# 23   12167  3.141675 2022-05-06 00:23:03      23  0.000082  0.000082
# 24   13824  3.141520 2022-05-06 00:24:03      24 -0.000072  0.000072
# 25   15625  3.141657 2022-05-06 00:25:04      25  0.000064  0.000064
# 26   17576  3.141536 2022-05-06 00:26:04      26 -0.000057  0.000057
# 27   19683  3.141643 2022-05-06 00:27:04      27  0.000051  0.000051
# 28   21952  3.141547 2022-05-06 00:28:04      28 -0.000046  0.000046
# 29   24389  3.141634 2022-05-06 00:29:04      29  0.000041  0.000041
#
#            test3         test4
# 0       1.000000      0.540302
# 1       0.540302      0.540302
# 2      -3.329175     -1.164000
# 3     -26.729797     -7.887748
# 4     -41.833192     25.078863
# 5      35.457773     98.464314
# 6     207.396782   -155.084778
# 7     258.588473   -289.436360
# 8     -74.496017   -510.378696
# 9    -664.213961    720.759078
# 10   -839.071529    562.379076
# 11      5.890604    679.183673
# 12   1458.179641   1714.723487
# 13   1993.660579  -1137.200280
# 14    375.206927   -494.450270
# 15  -2563.946706   2019.069096
# 16  -3922.573231   3293.145553
# 17  -1351.877480   4421.949666
# 18   3850.967042   2091.320766
# 19   6781.524976  -4246.207435
# 20   3264.656495    525.161020
# 21  -5072.520679   8474.359015
# 22 -10647.582879  -4422.373796
# 23  -6482.979358 -11260.997895
# 24   5863.850597   7558.206815
# 25  15487.543935   4452.090723
# 26  11370.254009  -6189.918603
# 27  -5750.168172 -11892.618490
# 28 -21131.123977   2656.972514
# 29 -18244.375092 -16705.797704

# %%
df['test3'] = df['factor'] * np.cos(df['minute'])
df['test4'] = df['factor'] * np.cos(df['factor'])
print(df.head())
# Out:
#    factor        pi                time  minute      test     test2  \
# 0       1  4.000000 2022-05-06 00:00:00       0  0.858407  1.000000
# 1       1  4.000000 2022-05-06 00:01:00       1  0.858407  1.000000
# 2       8  3.017072 2022-05-06 00:02:00       2 -0.124521  0.125000
# 3      27  3.178617 2022-05-06 00:03:00       3  0.037024  0.037037
# 4      64  3.125969 2022-05-06 00:04:00       4 -0.015624  0.015625
#
#        test3      test4
# 0   1.000000   0.540302
# 1   0.540302   0.540302
# 2  -3.329175  -1.164000
# 3 -26.729797  -7.887748
# 4 -41.833192  25.078863

# %%
x = np.arange(1, 60, 1)
y = x**3 * np.sin(x)
plt.plot(x, y)
